# %% [markdown]
# # Andmete puhastamine
#
# Siin töötleme varasemas etapis kogutud toorandmeid (`toorandmed_aasta.csv`).
#
# **Sisend:** `toorandmed_aasta.csv`
#
# **Väljund:** `andmed_aasta.csv`
#
# ### Samm 0: Teekide laadimine ja failiteede seadistamine
# Laeme vajalikud Pythoni teegid ja fikseerime sisend- ja väljundfailide asukohad. Loeme sisse puhastamata andmed.

# %%
import pandas as pd
import json
import numpy as np
import os

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)

INPUT_FILE = 'toorandmed_aasta.csv'
OUTPUT_FILE = 'andmed_aasta.csv'

if os.path.exists(INPUT_FILE):
    df = pd.read_csv(INPUT_FILE, low_memory=False)
    print(f"Toorandmed loetud. Andmestiku suurus: {df.shape[0]} rida, {df.shape[1]} veergu.")
else:
    raise FileNotFoundError(f"Viga: Sisendfaili '{INPUT_FILE}' ei leitud! Kontrolli failiteed.")

df.head(2)
# Out:
# Toorandmed loetud. Andmestiku suurus: 3156 rida, 229 veergu.
#                             course_uuid         code  \
# 0  b99c0bb1-efd4-9b0a-857a-3dc7114e5c19  OIEO.06.046
# 1  0e7d0b5d-83ea-f260-7e09-c3d59ea9c250  KKSB.05.092
#
#                           title__en                version__title__en  \
# 0         Private International Law         Private International Law
# 1  Practice in the Work Environment  Practice in the Work Environment
#
#    credits  \
# 0      6.0
# 1      3.0
#
#                                                                              overview__description__en  \
# 0  The course covers the main topics of private international law (PIL), its terminology and develo...
# 1  Subject Practicing in the work environment the students expand their knowledge in the field of p...
#
#                                                                     version__overview__description__en  \
# 0  The course covers the main topics of private international law (PIL), its terminology and develo...
# 1  Subject Practicing in the work environment the students expand their knowledge in the field of p...
#
#                                                                    overview__learning_outcomes_text_en  \
# 0  - At the end of the course the student is able to:\n- -\texplain the nature of the main institut...
# 1  - Student:\n- understands and follows the work ethic and organization in the work environment;;\...
#
#                                    uuid state__code   state__et  state__en  \
# 0  b99c0bb1-efd4-9b0a-857a-3dc7114e5c19   confirmed  Kinnitatud  confirmed
# 1  0e7d0b5d-83ea-f260-7e09-c3d59ea9c250   confirmed  Kinnitatud  confirmed
#
#            last_update                      title__et  \
# 0  2024-02-05T11:04:36        Rahvusvaheline eraõigus
# 1  2024-02-05T11:04:36  Praktiseerimine töökeskkonnas
#
#                                  general__input_languages  \
# 0  [{"code": "et", "en": "Estonian", "et": "eesti keel"}]
# 1  [{"code": "et", "en": "Estonian", "et": "eesti keel"}]
#
#                                                                        general__structural_unit_shares  \
# 0  [{"coordinating": true, "course_share_percent": 100, "structural_unit_code": "SVOI04", "structur...
# 1  [{"coordinating": true, "course_share_percent": 100, "structural_unit_code": "MVSF", "structural...
#
#   general__type__code general__type__et general__type__en  \
# 0             regular     Tavaline aine    Regular course
# 1             regular     Tavaline aine    Regular course
#
#                                                                              general__structural_units  \
# 0  [{"academic": true, "address": "Näituse 20-318\n50409 Tartu linn, \nTartu linn, Tartumaa \nEST",...
# 1  [{"academic": true, "address": "Ujula 4\n51008 Tartu linn, \nTartu linn, Tartumaa \nEST", "city"...
#
#    additional_info__duration_in_semesters  \
# 0                                       1
# 1                                       1
#
#   additional_info__assessment_scale__code  \
# 0                                   grade
# 1                                    pass
#
#   additional_info__assessment_scale__et  \
# 0        Eristav (A, B, C, D, E, F, mi)
# 1           Eristamata (arv, m.arv, mi)
#
#             additional_info__assessment_scale__en  \
# 0  differentiated (A, B, C, D, E, F, not present)
# 1    non-differentiated (pass, fail, not present)
#
#    additional_info__is_vota_course  \
# 0                             True
# 1                             True
#
#    additional_info__is_continuous_learning_course  \
# 0                                           False
# 1                                           False
#
#                                                                              overview__description__et  \
# 0  Kursuse raames käsitletakse rahvusvahelise eraõiguse põhiteemasid, terminoloogiat ja kujunemist,...
# 1  Aines Praktiseerimine töökeskkonnas laiendab üliõpilane oma silmaringi füsioteraapia valdkonnas ...
#
#                                                                                   overview__objectives  \
# 0  [{"en": "The purpose of the course is to teach the theoretical principles of private internation...
# 1  [{"en": "The aim of practice is gaining work experience in the work environment", "et": "Aine ee...
#
#                                                                            overview__learning_outcomes  \
# 0  [{"en": "At the end of the course the student is able to:", "et": "Kursuse lõpuks peab üliõpilan...
# 1  [{"en": "Student:", "et": "Õpilane:"}, {"en": "understands and follows the work ethic and organi...
#
#    _actions__is_editable  _actions__is_version_creatable  \
# 0                  False                           False
# 1                  False                           False
#
#    _actions__is_deletable  \
# 0                   False
# 1                   False
#
#                                                                           overview__objectives_text_en  \
# 0  - The purpose of the course is to teach the theoretical principles of private international law ...
# 1                             - The aim of practice is gaining work experience in the work environment
#
#                           version__uuid            version__code  \
# 0  814c854e-0af7-fb0a-6c8c-5f255cc4e277  sv-2025-spring-fulltime
# 1  2aa2a86d-6625-5771-49f7-90bfba6f0202                      NaN
#
#   version__state__code version__state__et version__state__en  \
# 0            confirmed         Kinnitatud          confirmed
# 1            confirmed         Kinnitatud          confirmed
#
#   version__last_update             version__title__et  version__credits  \
# 0  2025-11-04T13:12:16        Rahvusvaheline eraõigus               6.0
# 1  2026-01-15T10:10:30  Praktiseerimine töökeskkonnas               3.0
#
#   version__credit_type  version__target__year__code version__target__year__et  \
# 0                 ECTS                       2025.0                 2025/2026
# 1                 ECTS                       2025.0                 2025/2026
#
#   version__target__year__en version__target__semester__code  \
# 0                 2025/2026                          spring
# 1                 2025/2026                          spring
#
#   version__target__semester__et version__target__semester__en  \
# 0                         kevad                        spring
# 1                         kevad                        spring
#
#   version__target__study_type__code version__target__study_type__et  \
# 0                          fulltime                        päevaõpe
# 1                          fulltime                        päevaõpe
#
#   version__target__study_type__en version__target__language__code  \
# 0                 regular studies                              et
# 1                 regular studies                              et
#
#   version__target__language__et version__target__language__en  \
# 0                    eesti keel                      Estonian
# 1                    eesti keel                      Estonian
#
#    version__target__part__code version__target__part__et  \
# 0                          0.0                   Osadeta
# 1                          0.0                   Osadeta
#
#   version__target__part__en version__target__faculty__code  \
# 0                       NaN                             SV
# 1                       NaN                             MV
#
#   version__target__faculty__name__en version__target__faculty__name__et  \
# 0         Faculty of Social Sciences          sotsiaalteaduste valdkond
# 1                Faculty of Medicine        meditsiiniteaduste valdkond
#
#           version__target__faculty__address version__target__faculty__city  \
# 0  Tartu linn, \nTartu linn, Tartumaa \nEST                     Tartu linn
# 1  Tartu linn, \nTartu linn, Tartumaa \nEST                     Tartu linn
#
#    version__target__faculty__level version__target__faculty__academic  \
# 0                              1.0                               True
# 1                              1.0                               True
#
#   version__target__faculty__supports_continuous_learning  \
# 0                                                   True
# 1                                                   True
#
#   version__target__course_main_structural_unit__code  \
# 0                                             SVOI04
# 1                                               MVSF
#
#   version__target__course_main_structural_unit__name__en  \
# 0                              Department of Private Law
# 1          Institute of Sport Sciences and Physiotherapy
#
#   version__target__course_main_structural_unit__name__et  \
# 0                                      eraõiguse osakond
# 1              sporditeaduste ja füsioteraapia instituut
#
#   version__target__course_main_structural_unit__webpage_url  \
# 0             https://oi.ut.ee/et/kontakt/eraoiguse-osakond
# 1                              https://sporditeadused.ut.ee
#
#             version__target__course_main_structural_unit__address  \
# 0  Näituse 20-318\n50409 Tartu linn, \nTartu linn, Tartumaa \nEST
# 1         Ujula 4\n51008 Tartu linn, \nTartu linn, Tartumaa \nEST
#
#   version__target__course_main_structural_unit__city  \
# 0                                         Tartu linn
# 1                                         Tartu linn
#
#   version__target__course_main_structural_unit__street  \
# 0                                       Näituse 20-318
# 1                                              Ujula 4
#
#    version__target__course_main_structural_unit__zip  \
# 0                                            50409.0
# 1                                            51008.0
#
#    version__target__course_main_structural_unit__level  \
# 0                                                  3.0
# 1                                                  2.0
#
#   version__target__course_main_structural_unit__academic  \
# 0                                                   True
# 1                                                   True
#
#   version__target__course_main_structural_unit__supports_continuous_learning  \
# 0                                                                      False
# 1                                                                       True
#
#   version__target__course_main_structural_unit__parent_code  \
# 0                                                      SVOI
# 1                                                        MV
#
#   version__target__label__en version__target__label__et  \
# 0         25/26 S regular SV              25/26 K PÕ SV
# 1         25/26 S regular MV              25/26 K PÕ MV
#
#    version__general__year__code version__general__year__et  \
# 0                        2025.0                  2025/2026
# 1                        2025.0                  2025/2026
#
#   version__general__year__en  \
# 0                  2025/2026
# 1                  2025/2026
#
#                         version__general__input_languages  \
# 0  [{"code": "et", "en": "Estonian", "et": "eesti keel"}]
# 1  [{"code": "et", "en": "Estonian", "et": "eesti keel"}]
#
#                                                               version__general__structural_unit_shares  \
# 0  [{"coordinating": true, "course_share_percent": 100, "structural_unit_code": "SVOI04", "structur...
# 1  [{"coordinating": true, "course_share_percent": 100, "structural_unit_code": "MVSF", "structural...
#
#   version__general__type__code version__general__type__et  \
# 0                      regular              Tavaline aine
# 1                      regular              Tavaline aine
#
#   version__general__type__en version__additional_info__is_vota_course  \
# 0             Regular course                                     True
# 1             Regular course                                     True
#
#   version__additional_info__is_continuous_learning_course  \
# 0                                                   False
# 1                                                   False
#
#                                         version__additional_info__study_levels  \
# 0          [{"code": "master", "en": "master's studies", "et": "magistriõpe"}]
# 1  [{"code": "bachelor", "en": "bachelor's studies", "et": "bakalaureuseõpe"}]
#
#    version__additional_info__hours__lecture  \
# 0                                      20.0
# 1                                       0.0
#
#    version__additional_info__hours__practice  \
# 0                                        0.0
# 1                                        0.0
#
#    version__additional_info__hours__seminar  \
# 0                                      24.0
# 1                                       0.0
#
#    version__additional_info__hours__colloquium  \
# 0                                          0.0
# 1                                          0.0
#
#    version__additional_info__hours__web_learning  \
# 0                                            0.0
# 1                                            0.0
#
#    version__additional_info__hours__independent_work  \
# 0                                              112.0
# 1                                                0.0
#
#    version__additional_info__hours__individual_work  \
# 0                                               0.0
# 1                                               0.0
#
#    version__additional_info__hours__internship  \
# 0                                          0.0
# 1                                         78.0
#
#   version__additional_info__is_enlight_course  \
# 0                                       False
# 1                                       False
#
#                        version__overview__study_languages  \
# 0  [{"code": "et", "en": "Estonian", "et": "eesti keel"}]
# 1  [{"code": "et", "en": "Estonian", "et": "eesti keel"}]
#
#                                                                     version__overview__description__et  \
# 0  Kursuse raames käsitletakse rahvusvahelise eraõiguse põhiteemasid, terminoloogiat ja kujunemist,...
# 1  Aines Praktiseerimine töökeskkonnas laiendab üliõpilane oma silmaringi füsioteraapia valdkonnas ...
#
#                                                                          version__overview__objectives  \
# 0  [{"en": "The purpose of the course is to teach the theoretical principles of private internation...
# 1  [{"en": "The aim of practice is gaining work experience in the work environment", "et": "Aine ee...
#
#                                                                   version__overview__learning_outcomes  \
# 0  [{"en": "At the end of the course the student is able to:", "et": "Kursuse lõpuks peab üliõpilan...
# 1  [{"en": "Student:", "et": "Õpilane:"}, {"en": "understands and follows the work ethic and organi...
#
#                                                         version__grading__independent_work_assessments  \
# 0  [{"description": {"et": "Avatud küsimuste hindamiskriteeriumid (osa eksamist, 2-3 tk):\n*\tViide...
# 1  [{"description": {"et": "Hindamismeetod on mitteeristav (arvestatud/mitte-arvestatud)\nLävendikr...
#
#   version__grading__grade_preconditions__et  \
# 0           Aktiivne osalemine seminarides.
# 1               Nõutava tähtaegne esitamine
#
#   version__grading__grade_evaluation__et  \
# 0                   100% kirjalik eksam.
# 1                                    NaN
#
#                                                       version__grading__debt_elimination__et  \
# 0                          Puudutud seminaride järelevastamine toimub kokkuleppel õppejõuga.
# 1  Võlgnevuste likvideerimine lepitakse kokku vastutava õppejõu ja praktika juhendaja(te)ga.
#
#   version__grading__assessment_scale__code  \
# 0                                    grade
# 1                                     pass
#
#   version__grading__assessment_scale__et  \
# 0         Eristav (A, B, C, D, E, F, mi)
# 1            Eristamata (arv, m.arv, mi)
#
#            version__grading__assessment_scale__en  \
# 0  differentiated (A, B, C, D, E, F, not present)
# 1    non-differentiated (pass, fail, not present)
#
#    version__resources__web_based__code version__resources__web_based__et  \
# 0                                  2.0                           põimõpe
# 1                                  2.0                           põimõpe
#
#   version__resources__web_based__en version__resources__website_url  \
# 0                  blended learning             http://moodle.ut.ee
# 1                  blended learning             http://moodle.ut.ee
#
#   version__resources__is_moodle_connected  \
# 0                                    True
# 1                                   False
#
#                                                              version__resources__learning_environments  \
# 0  [{"base_url": "https://moodle.ut.ee/local/ois", "code": "OIEO.06.046", "is_auto_grading": false,...
# 1                                                                                                  NaN
#
#                                                                          version__resources__materials  \
# 0  [{"name": {"et": "Ainekursusel käsitletud õigusaktid ja kohtupraktika."}, "required": true, "typ...
# 1                                                                                                  NaN
#
#                                                                       version__participants__lecturers  \
# 0  [{"is_responsible": true, "is_teaching": true, "person_name": "Gea Lepik", "person_uuid": "d7a3f...
# 1  [{"is_responsible": true, "is_teaching": true, "person_name": "Kadri Medijainen", "person_uuid":...
#
#         version__schedule__weeks__et  \
# 0  Loengud: 24-28 ; Seminarid: 29-34
# 1                              40-52
#
#                                                                             version__schedule__entries  \
# 0  [{"course_week": 1, "description": {"et": "Sissejuhatus. Rahvusvaheline kohtualluvus tsiviil- ja...
# 1  [{"description": {"et": "Õppeaine raames toimuvale vabatahtlikule praktikale eelnevalt peab olem...
#
#                    version__parent_uuid version__parent_code  \
# 0  b99c0bb1-efd4-9b0a-857a-3dc7114e5c19          OIEO.06.046
# 1  0e7d0b5d-83ea-f260-7e09-c3d59ea9c250          KKSB.05.092
#
#    version__parent_credits version___actions__is_editable  \
# 0                      6.0                          False
# 1                      3.0                          False
#
#   version___actions__is_moodle_editable version___actions__is_deletable  \
# 0                                 False                           False
# 1                                 False                           False
#
#                                                                  version__overview__objectives_text_en  \
# 0  - The purpose of the course is to teach the theoretical principles of private international law ...
# 1                             - The aim of practice is gaining work experience in the work environment
#
#                                                           version__overview__learning_outcomes_text_en  \
# 0  - At the end of the course the student is able to:\n- -\texplain the nature of the main institut...
# 1  - Student:\n- understands and follows the work ethic and organization in the work environment;;\...
#
#                     latest_version_uuid  \
# 0  814c854e-0af7-fb0a-6c8c-5f255cc4e277
# 1  2aa2a86d-6625-5771-49f7-90bfba6f0202
#
#   additional_info__occurrence_frequency__code  \
# 0                                         NaN
# 1                                        year
#
#   additional_info__occurrence_frequency__et  \
# 0                                       NaN
# 1                           igal õppeaastal
#
#   additional_info__occurrence_frequency__en  version__target__part_credits  \
# 0                                       NaN                            NaN
# 1                       every academic year                            NaN
#
#   version__target__course_main_structural_unit__phone  \
# 0                                                 NaN
# 1                                       +372 737 5360
#
#                                                                 version__grading__independent_work__et  \
# 0                                                                                                  NaN
# 1  80 h praktikilise kogemuse kohta tuleb täita õpimapi kõik osad ((blankett aine Moodle`is). Lisak...
#
#   version__resources__mandatory_materials  \
# 0                                     NaN
# 1                                     NaN
#
#   version__resources__recommended_materials  \
# 0                                       NaN
# 1                                       NaN
#
#    version__registration_info__min_students  \
# 0                                       NaN
# 1                                       1.0
#
#   version__target__course_main_structural_unit__email  \
# 0                                                 NaN
# 1                                         kkdek@ut.ee
#
#                                                                           version__overview__notes__et  \
# 0                                                                                                  NaN
# 1  NB! Praktikakoha selleks vabatahtlikuks praktikaks organiseerib endale üliõpilane ise. Prkatikab...
#
#   version__participants__study_groups  \
# 0                                 NaN
# 1                                 NaN
#
#    version__registration_info__max_students  \
# 0                                       NaN
# 1                                      80.0
#
#                        version__overview__other_languages  \
# 0                                                     NaN
# 1  [{"code": "et", "en": "Estonian", "et": "eesti keel"}]
#
#    version__registration_info__audience__et additional_info__prerequisites  \
# 0                                       NaN                            NaN
# 1  läbitud vähemalt üks kliiniline praktika                            NaN
#
#   version__participants__assistants  \
# 0                               NaN
# 1                               NaN
#
#   version__target__course_main_structural_unit__is_expired  \
# 0                                                      NaN
# 1                                                      NaN
#
#   version__grading__grade_conditions__arvestatud__et  \
# 0                                                NaN
# 1                                                NaN
#
#   version__grading__grade_conditions__mittearvestatud__et  \
# 0                                                     NaN
# 1                                                     NaN
#
#   version__grading__grade_conditions__mitteilmunud__et  \
# 0                                                  NaN
# 1                                                  NaN
#
#   version__confirmation_process__confirmation_uuid  \
# 0                                              NaN
# 1                                              NaN
#
#   version__confirmation_process__state_code  \
# 0                                       NaN
# 1                                       NaN
#
#   version__confirmation_process__is_paused  \
# 0                                      NaN
# 1                                      NaN
#
#   version__grading__grade_conditions__A__et  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_conditions__B__et  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_conditions__C__et  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_conditions__D__et  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_conditions__E__et  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_conditions__F__et  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_conditions__mi__et  \
# 0                                        NaN
# 1                                        NaN
#
#   additional_info__language_training__language__code  \
# 0                                                NaN
# 1                                                NaN
#
#   additional_info__language_training__language__et  \
# 0                                              NaN
# 1                                              NaN
#
#   additional_info__language_training__language__en  \
# 0                                              NaN
# 1                                              NaN
#
#   version__additional_info__language_training__language__code  \
# 0                                                         NaN
# 1                                                         NaN
#
#   version__additional_info__language_training__language__et  \
# 0                                                       NaN
# 1                                                       NaN
#
#   version__additional_info__language_training__language__en  \
# 0                                                       NaN
# 1                                                       NaN
#
#   version__additional_info__language_training__start_level__code  \
# 0                                                            NaN
# 1                                                            NaN
#
#   version__additional_info__language_training__start_level__et  \
# 0                                                          NaN
# 1                                                          NaN
#
#   version__additional_info__language_training__start_level__en  \
# 0                                                          NaN
# 1                                                          NaN
#
#   version__additional_info__language_training__end_level__code  \
# 0                                                          NaN
# 1                                                          NaN
#
#   version__additional_info__language_training__end_level__et  \
# 0                                                        NaN
# 1                                                        NaN
#
#   version__additional_info__language_training__end_level__en  \
# 0                                                        NaN
# 1                                                        NaN
#
#   additional_info__language_training__start_level__code  \
# 0                                                   NaN
# 1                                                   NaN
#
#   additional_info__language_training__start_level__et  \
# 0                                                 NaN
# 1                                                 NaN
#
#   additional_info__language_training__start_level__en  \
# 0                                                 NaN
# 1                                                 NaN
#
#    version__grading__min_points_from_tests  \
# 0                                      NaN
# 1                                      NaN
#
#   version__grading__results_available_from__et  \
# 0                                          NaN
# 1                                          NaN
#
#   version__grading__independent_work__en  \
# 0                                    NaN
# 1                                    NaN
#
#   version__grading__grade_preconditions__en  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_evaluation__en  \
# 0                                    NaN
# 1                                    NaN
#
#   version__grading__debt_elimination__en version__overview__notes__en  \
# 0                                    NaN                          NaN
# 1                                    NaN                          NaN
#
#   version__grading__results_available_from__en  \
# 0                                          NaN
# 1                                          NaN
#
#   version__grading__grade_conditions__arvestatud__en  \
# 0                                                NaN
# 1                                                NaN
#
#   version__grading__grade_conditions__mittearvestatud__en  \
# 0                                                     NaN
# 1                                                     NaN
#
#   version__grading__grade_conditions__mitteilmunud__en  \
# 0                                                  NaN
# 1                                                  NaN
#
#   additional_info__complex_course_sub_courses  \
# 0                                         NaN
# 1                                         NaN
#
#   additional_info__language_training__end_level__code  \
# 0                                                 NaN
# 1                                                 NaN
#
#   additional_info__language_training__end_level__et  \
# 0                                               NaN
# 1                                               NaN
#
#   additional_info__language_training__end_level__en  \
# 0                                               NaN
# 1                                               NaN
#
#   additional_info__language_training__is_in_depth_estonian_training  \
# 0                                                               NaN
# 1                                                               NaN
#
#   version__additional_info__language_training__is_in_depth_estonian_training  \
# 0                                                                        NaN
# 1                                                                        NaN
#
#   version__grading__grade_conditions__A__en  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_conditions__B__en  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_conditions__C__en  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_conditions__D__en  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_conditions__E__en  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_conditions__F__en  \
# 0                                       NaN
# 1                                       NaN
#
#   version__grading__grade_conditions__mi__en version__target__faculty__email  \
# 0                                        NaN                             NaN
# 1                                        NaN                             NaN
#
#   version__target__faculty__phone version__target__faculty__webpage_url  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
#
#   version__target__faculty__street  version__target__faculty__zip  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
#
#   version__target__faculty__parent_code overview__description__ru  \
# 0                                   NaN                       NaN
# 1                                   NaN                       NaN
#
#   overview__description__fr title__vro overview__description__vro  \
# 0                       NaN        NaN                        NaN
# 1                       NaN        NaN                        NaN
#
#   version__title__vro version__overview__description__vro title__ru  \
# 0                 NaN                                 NaN       NaN
# 1                 NaN                                 NaN       NaN
#
#   version__title__ru version__confirmation_process__comment  \
# 0                NaN                                    NaN
# 1                NaN                                    NaN
#
#   version__resources__library_package  title__es  overview__description__es  \
# 0                                 NaN        NaN                        NaN
# 1                                 NaN        NaN                        NaN
#
#    version__title__es  version__overview__description__es  \
# 0                 NaN                                 NaN
# 1                 NaN                                 NaN
#
#   overview__description__de overview__description__da  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
#
#   version__overview__description__da version__target__faculty__is_expired  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
#
#   overview__objectives_text_et overview__learning_outcomes_text_et  \
# 0                          NaN                                 NaN
# 1                          NaN                                 NaN
#
#   version__overview__objectives_text_et  \
# 0                                   NaN
# 1                                   NaN
#
#   version__overview__learning_outcomes_text_et title__de version__title__de
# 0                                          NaN       NaN                NaN
# 1                                          NaN       NaN                NaN

# %% [markdown]
# ### Samm 1: Eemaldame andmed, mida me ei taha
#
# Filtreerime välja read, mis ei sobi meie rakenduse jaoks:
# - **`additional_info__duration_in_semesters`** — viskame ära read, kus see on suurem kui 1
# - **`version__target__study_type__et`** — jätame ainult päevaõppe ained
# - **`general__type__et`** — jätame ainult tavalised ained (välistame praktikad, kaitsmised, kompleksained)

# %%
print(f"Ridu enne filtreerimist: {len(df)}")

if 'additional_info__duration_in_semesters' in df.columns:
    mask_duration = df['additional_info__duration_in_semesters'] <= 1
    df = df[mask_duration]
    print(f"Pärast kestuse filtrit (<=1 semester): {len(df)} rida")

if 'version__target__study_type__et' in df.columns:
    mask_study_type = df['version__target__study_type__et'].isna() | df['version__target__study_type__et'].str.contains('päevaõ', case=False, na=False)
    df = df[mask_study_type]
    print(f"Pärast õppetüübi filtrit (päevaõpe): {len(df)} rida")

if 'general__type__et' in df.columns:
    print(f"general__type__et väärtused enne filtrit:\n{df['general__type__et'].value_counts()}")
    mask_type = df['general__type__et'].str.contains('Tavaline', case=False, na=False)
    df = df[mask_type]
    print(f"\nPärast aine tüübi filtrit (Tavaline aine): {len(df)} rida")

print(f"\nLõplik ridade arv pärast filtreerimist: {len(df)}")
# Out:
# Ridu enne filtreerimist: 3156
# Pärast kestuse filtrit (<=1 semester): 3156 rida
# Pärast õppetüübi filtrit (päevaõpe): 3156 rida
# general__type__et väärtused enne filtrit:
# general__type__et
# Tavaline aine              2954
# Praktika                    138
# Kaitsmisega lõppev aine      58
# Kompleksaine                  6
# Name: count, dtype: int64
#
# Pärast aine tüübi filtrit (Tavaline aine): 2954 rida
#
# Lõplik ridade arv pärast filtreerimist: 2954

# %% [markdown]
# ### Samm 2: Puhastatud veergude lisamine
#
# Valime välja huvipakkuvad veerud ning puhastame need. Eelistame alati `version__` prefiksiga veerge, sest need kajastavad tegelikku aineprogrammi. Kui see puudub, võtame üldise info.

# %%
def resolve_fields(df):
    """
    Loob uued puhtad veerud, eelistades versiooni-põhist infot.
    Tagastab täiendatud DataFrame'i.
    """
    merge_mapping = [
        ('nimi_et', 'title__et', 'version__title__et'),
        ('nimi_en', 'title__en', 'version__title__en'),
        ('eap', 'credits', 'version__credits'),
        ('kirjeldus_et', 'overview__description__et', 'version__overview__description__et'),
        ('kirjeldus_en', 'overview__description__en', 'version__overview__description__en'),
        ('oppivaaljundid_en', 'overview__learning_outcomes_text_en', 'version__overview__learning_outcomes_text_en'),
        ('oppivaaljundid_et', 'overview__learning_outcomes_text_et', 'version__overview__learning_outcomes_text_et'),
        ('keel_et', 'version__target__language__et', None),
        ('keel_en', 'version__target__language__en', None),
    ]

    rename_mapping = [
        ('aine_kood', 'code'),
        ('semester', 'version__target__semester__et'),
        ('hindamisskaala', 'additional_info__assessment_scale__et'),
        ('linn', 'version__target__course_main_structural_unit__city'),
        ('hindamine', 'version__grading__grade_evaluation__et'),
        ('taiskoormus', 'additional_info__is_continuous_learning_course'),
        ('kestus_semestrites', 'additional_info__duration_in_semesters'),
        ('oppe_tuup', 'version__target__study_type__et'),
        ('aine_tuup', 'general__type__et'),
        ('eeldusained_json', 'additional_info__prerequisites'),
        ('oppeaste_json', 'version__additional_info__study_levels'),
    ]

    print("Alustan veergude filtreerimist ja ühendamist...")

    for new_col, base, version in merge_mapping:
        base_exists = base in df.columns if base else False
        ver_exists = version in df.columns if version else False
        if base_exists and ver_exists:
            df[new_col] = df[version].fillna(df[base])
        elif ver_exists:
            df[new_col] = df[version]
        elif base_exists:
            df[new_col] = df[base]
        else:
            df[new_col] = np.nan

    for new_col, source in rename_mapping:
        if source in df.columns:
            df[new_col] = df[source]
        else:
            df[new_col] = np.nan

    return df

df_resolved = resolve_fields(df.copy())

print(f"Samm 2: Puhastatud veergude lisamine tehtud.")
print(f"\nPuuduvate väärtuste arv uutes veergudes:")
new_cols = ['aine_kood', 'nimi_et', 'nimi_en', 'eap', 'semester', 'kirjeldus_et', 'kirjeldus_en',
            'oppivaaljundid_en', 'oppivaaljundid_et', 'keel_et', 'keel_en',
            'hindamisskaala', 'linn', 'hindamine', 'taiskoormus',
            'kestus_semestrites', 'oppe_tuup', 'aine_tuup',
            'eeldusained_json', 'oppeaste_json']
print(df_resolved[new_cols].isnull().sum())
# Out:
# Alustan veergude filtreerimist ja ühendamist...
# Samm 2: Puhastatud veergude lisamine tehtud.
#
# Puuduvate väärtuste arv uutes veergudes:
# aine_kood                0
# nimi_et                  0
# nimi_en                  0
# eap                      0
# semester                17
# kirjeldus_et             0
# kirjeldus_en             0
# oppivaaljundid_en        1
# oppivaaljundid_et     1471
# keel_et                 17
# keel_en                 17
# hindamisskaala           0
# linn                  1131
# hindamine              344
# taiskoormus              0
# kestus_semestrites       0
# oppe_tuup               17
# aine_tuup                0
# eeldusained_json      2432
# oppeaste_json           52
# dtype: int64

# %% [markdown]
# ### Samm 3: JSON väljade parsimine
#
# Parsime 2 JSON veergu:
# - **Eeldusained** — eraldame ainete koodid ja nimetused
# - **Õppeaste** — eraldame taseme (bakalaureus, magister, doktor)

# %%
def parse_json_safe(json_str):
    """Teisendab JSON-stringi turvaliselt Pythoni objektiks."""
    if pd.isna(json_str) or json_str == '':
        return None
    try:
        return json.loads(json_str)
    except (json.JSONDecodeError, TypeError):
        return None

def extract_prerequisites(json_str):
    """Eraldab eeldusainete koodid ja nimed."""
    data = parse_json_safe(json_str)
    if not data: return None
    courses = []
    for item in data:
        if not isinstance(item, dict): continue
        code = item.get('code', '')
        title_obj = item.get('title', {})
        title = title_obj.get('et', title_obj.get('en', '')) if isinstance(title_obj, dict) else ''
        if code and title:
            courses.append(f"{code} - {title}")
        for alt in item.get('alternatives', []):
            if not isinstance(alt, dict): continue
            alt_code = alt.get('code', '')
            alt_title_obj = alt.get('title', {})
            alt_title = alt_title_obj.get('et', alt_title_obj.get('en', '')) if isinstance(alt_title_obj, dict) else ''
            if alt_code and alt_title:
                courses.append(f"{alt_code} - {alt_title}")
    return "; ".join(courses) if courses else None

def extract_study_levels(json_str):
    """Eraldab õppeastme nimetused eesti keeles."""
    data = parse_json_safe(json_str)
    if not data: return None
    levels = []
    for item in data:
        if not isinstance(item, dict): continue
        level_et = item.get('et', item.get('en', ''))
        if level_et:
            levels.append(level_et)
    return ", ".join(levels) if levels else None

print("Ekstraheerime JSON väljadest infot...")
df_resolved['eeldusained'] = df_resolved['eeldusained_json'].apply(extract_prerequisites)
df_resolved['oppeaste'] = df_resolved['oppeaste_json'].apply(extract_study_levels)

print("Samm 3: JSON töötlemine valmis.\n")
print(df_resolved[['aine_kood', 'eeldusained', 'oppeaste']].dropna(subset=['eeldusained']).head(3))
# Out:
# Ekstraheerime JSON väljadest infot...
# Samm 3: JSON töötlemine valmis.
#
#      aine_kood  \
# 2  ARKI.02.030
# 3  LOFY.04.041
# 7  LOFY.04.035
#
#                                                                 eeldusained  \
# 2                                          AR00.00.016 - Diagnostika alused
# 3                LOFY.04.073 - Kvantmehaanika; LTFY.04.001 - Kvantmehaanika
# 7  LTFY.04.013 - Matemaatiline füüsika; LTFY.04.002 - Matemaatiline füüsika
#
#                                      oppeaste
# 2  integreeritud bakalaureuse- ja magistriõpe
# 3                     magistriõpe, doktoriõpe
# 7                             bakalaureuseõpe

# %% [markdown]
# ### Samm 4: Info koondamine mitmest allikast
#
# Koondame hindamisinfo mitmest veerust üheks tekstiks.

# %%
grading_source_cols = [
    ('Miinimumnõuded', 'version__grading__grade_preconditions__et'),
    ('Hindamismeetod', 'version__grading__grade_evaluation__et')
]

def combine_grading_info(row):
    """Koondab hindamisinfo mitmest veerust üheks tekstiks."""
    parts = []
    for label, col in grading_source_cols:
        val = row.get(col)
        if pd.notna(val) and str(val).strip():
            parts.append(f"{label}: {str(val).strip()}")
    return "\n".join(parts) if parts else None

df_resolved['hindamine_info'] = df_resolved.apply(combine_grading_info, axis=1)
print("Samm 4: Hindamisinfo koondatud.")
print(f"Puuduvaid väärtusi: {df_resolved['hindamine_info'].isna().sum()}")
print(f"\nNäide:")
sample = df_resolved['hindamine_info'].dropna().iloc[0]
print(sample[:300])
# Out:
# Samm 4: Hindamisinfo koondatud.
# Puuduvaid väärtusi: 192
#
# Näide:
# Miinimumnõuded: Aktiivne osalemine seminarides.
# Hindamismeetod: 100% kirjalik eksam.

# %% [markdown]
# ### Samm 5: Lõplik viimistlus
#
# Valime lõplikud veerud.

# %%
final_cols = [
    'aine_kood', 'nimi_et', 'nimi_en', 'eap', 'semester',
    'keel_et', 'keel_en', 'linn', 'oppeaste', 'hindamisskaala',
    'kirjeldus_et', 'kirjeldus_en',
    'oppivaaljundid_et', 'oppivaaljundid_en',
    'hindamine_info', 'eeldusained',
    'taiskoormus', 'kestus_semestrites', 'oppe_tuup', 'aine_tuup'
]

existing_cols = [c for c in final_cols if c in df_resolved.columns]
df_final = df_resolved[existing_cols].copy()

print(f"Lõplik ridade arv: {len(df_final)}, lõplik veergude arv: {len(df_final.columns)}")
print(f"Veerud: {list(df_final.columns)}")
print("Samm 5: Lõplik andmestik koostatud.")
# Out:
# Lõplik ridade arv: 2954, lõplik veergude arv: 20
# Veerud: ['aine_kood', 'nimi_et', 'nimi_en', 'eap', 'semester', 'keel_et', 'keel_en', 'linn', 'oppeaste', 'hindamisskaala', 'kirjeldus_et', 'kirjeldus_en', 'oppivaaljundid_et', 'oppivaaljundid_en', 'hindamine_info', 'eeldusained', 'taiskoormus', 'kestus_semestrites', 'oppe_tuup', 'aine_tuup']
# Samm 5: Lõplik andmestik koostatud.

# %% [markdown]
# ### Samm 6: Salvestamine ja kontroll

# %%
df_final.to_csv(OUTPUT_FILE, index=False)
print(f"Andmestik salvestatud faili '{OUTPUT_FILE}'.\n")

print("=" * 60)
print("PUUDUVATE VÄÄRTUSTE HULK IGAS VEERUS")
print("=" * 60)
missing = df_final.isnull().sum()
total = len(df_final)
missing_pct = (missing / total * 100).round(1)
missing_df = pd.DataFrame({'Puuduvaid': missing, 'Protsent (%)': missing_pct})
print(missing_df)
print()
# Out:
# Andmestik salvestatud faili 'andmed_aasta.csv'.
#
# ============================================================
# PUUDUVATE VÄÄRTUSTE HULK IGAS VEERUS
# ============================================================
#                     Puuduvaid  Protsent (%)
# aine_kood                   0           0.0
# nimi_et                     0           0.0
# nimi_en                     0           0.0
# eap                         0           0.0
# semester                   17           0.6
# keel_et                    17           0.6
# keel_en                    17           0.6
# linn                     1131          38.3
# oppeaste                   52           1.8
# hindamisskaala              0           0.0
# kirjeldus_et                0           0.0
# kirjeldus_en                0           0.0
# oppivaaljundid_et        1471          49.8
# oppivaaljundid_en           1           0.0
# hindamine_info            192           6.5
# eeldusained              2432          82.3
# taiskoormus                 0           0.0
# kestus_semestrites          0           0.0
# oppe_tuup                  17           0.6
# aine_tuup                   0           0.0

# %%
print("=" * 60)
print("KATEGOORILISTE TUNNUSTE ENIM LEVINUD VÄÄRTUSED")
print("=" * 60)

categorical_cols = ['keel_et', 'semester', 'oppeaste', 'hindamisskaala', 'linn',
                    'taiskoormus', 'kestus_semestrites', 'oppe_tuup', 'aine_tuup']

for col in categorical_cols:
    if col in df_final.columns:
        print(f"\n--- {col} ---")
        print(df_final[col].value_counts().head(5))
        print()
# Out:
# ============================================================
# KATEGOORILISTE TUNNUSTE ENIM LEVINUD VÄÄRTUSED
# ============================================================
#
# --- keel_et ---
# keel_et
# eesti keel      2176
# inglise keel     761
# Name: count, dtype: int64
#
#
# --- semester ---
# semester
# sügis    1489
# kevad    1448
# Name: count, dtype: int64
#
#
# --- oppeaste ---
# oppeaste
# bakalaureuseõpe                               907
# magistriõpe                                   517
# bakalaureuseõpe, magistriõpe                  302
# integreeritud bakalaureuse- ja magistriõpe    238
# bakalaureuseõpe, magistriõpe, doktoriõpe      216
# Name: count, dtype: int64
#
#
# --- hindamisskaala ---
# hindamisskaala
# Eristav (A, B, C, D, E, F, mi)    1774
# Eristamata (arv, m.arv, mi)       1180
# Name: count, dtype: int64
#
#
# --- linn ---
# linn
# Tartu linn         1550
# Narva linn          118
# Viljandi linn       108
# Pärnu linn           31
# Tõravere alevik      11
# Name: count, dtype: int64
#
#
# --- taiskoormus ---
# taiskoormus
# False    1970
# True      984
# Name: count, dtype: int64
#
#
# --- kestus_semestrites ---
# kestus_semestrites
# 1    2954
# Name: count, dtype: int64
#
#
# --- oppe_tuup ---
# oppe_tuup
# päevaõpe    2937
# Name: count, dtype: int64
#
#
# --- aine_tuup ---
# aine_tuup
# Tavaline aine    2954
# Name: count, dtype: int64

# %%
print("=" * 60)
print("AINE: SISSEJUHATUS ANDMETEADUSESSE")
print("=" * 60)

mask = df_final['nimi_et'].str.contains('Sissejuhatus andmeteadusesse', case=False, na=False)
sissejuhatus = df_final[mask]

if len(sissejuhatus) == 0:
    print("Ainet 'Sissejuhatus andmeteadusesse' ei leitud! Proovime laiema otsinguga...")
    mask = df_final['nimi_et'].str.contains('andmeteadus', case=False, na=False)
    sissejuhatus = df_final[mask]

if len(sissejuhatus) > 0:
    row = sissejuhatus.iloc[0]
    line = chr(9472) * 50
    print(f"\n{line}")
    print(f"  Aine kood:        {row.get('aine_kood', 'N/A')}")
    print(f"  Nimi (ET):        {row.get('nimi_et', 'N/A')}")
    print(f"  Nimi (EN):        {row.get('nimi_en', 'N/A')}")
    print(f"  EAP:              {row.get('eap', 'N/A')}")
    print(f"  Semester:         {row.get('semester', 'N/A')}")
    print(f"  Keel:             {row.get('keel_et', 'N/A')}")
    print(f"  Linn:             {row.get('linn', 'N/A')}")
    print(f"  Õppeaste:         {row.get('oppeaste', 'N/A')}")
    print(f"  Hindamisskaala:   {row.get('hindamisskaala', 'N/A')}")
    print(f"  Täiskoormus:      {row.get('taiskoormus', 'N/A')}")
    print(f"  Kestus (sem.):    {row.get('kestus_semestrites', 'N/A')}")
    print(f"  Õppe tüüp:        {row.get('oppe_tuup', 'N/A')}")
    print(f"  Aine tüüp:        {row.get('aine_tuup', 'N/A')}")
    print(f"  Eeldusained:      {row.get('eeldusained', 'N/A')}")
    print(f"{line}")
    print(f"\n  Kirjeldus (ET):")
    print(f"  {row.get('kirjeldus_et', 'N/A')}")
    print(f"\n  Kirjeldus (EN):")
    print(f"  {row.get('kirjeldus_en', 'N/A')}")
    print(f"\n  Õpiväljundid (ET):")
    print(f"  {row.get('oppivaaljundid_et', 'N/A')}")
    print(f"\n  Õpiväljundid (EN):")
    print(f"  {row.get('oppivaaljundid_en', 'N/A')}")
    print(f"\n  Hindamise info:")
    print(f"  {row.get('hindamine_info', 'N/A')}")
    print(f"{line}")
else:
    print("Ainet ei leitud andmestikust.")
# Out:
# ============================================================
# AINE: SISSEJUHATUS ANDMETEADUSESSE
# ============================================================
#
# ──────────────────────────────────────────────────
#   Aine kood:        LTAT.02.002
#   Nimi (ET):        Sissejuhatus andmeteadusesse
#   Nimi (EN):        Introduction to Data Science
#   EAP:              6.0
#   Semester:         sügis
#   Keel:             inglise keel
#   Linn:             nan
#   Õppeaste:         bakalaureuseõpe, magistriõpe
#   Hindamisskaala:   Eristav (A, B, C, D, E, F, mi)
#   Täiskoormus:      True
#   Kestus (sem.):    1
#   Õppe tüüp:        päevaõpe
#   Aine tüüp:        Tavaline aine
#   Eeldusained:      None
# ──────────────────────────────────────────────────
#
#   Kirjeldus (ET):
#   Kursus annab lühiülevaate andmeteaduse põhimõistetest, põhiprintsiipidest ning praktilistest aspektidest. Lõppeesmärk on õppida planeerima ning läbi viima lihtsat praktilist andmeteaduse projekti. Kursus käsitleb peamisi andmete kirjeldava analüüsi ning visualiseerimise meetodeid, sagedaste mustrite otsimist, klasteranalüüsi, peakomponentanalüüsi, peamisi masinõppemeetodeid klassifitseerimise ja regressiooni jaoks (sealhulgas sügavaid neurovõrke), andmete haldamist ning statistiliste testide interpreteerimist. Tutvutakse andmeteaduse projekti põhiliste etappidega ning tarkvaraliste töövahenditega. Peamiseks töövahendiks Õpime projekti ellu viima baseerudes programmeerimiskeele Python teekidele. Kodutööde lahendamiseks on kasutusel programmeerimiskeel Python 3 ja selle teegid.
#
#   Kirjeldus (EN):
#   This course gives a brief overview of the basic concepts, principles and practice of data science. The main goal is to learn to plan and carry out a simple practical data science project. The course covers the main methods for descriptive data analysis and visualization, frequent pattern mining, cluster analysis, principal components analysis, common methods of machine learning for classification and regression (including deep neural networks), managing data and interpreting results of statistical tests. The main stages of data science projects are dicussed and available software tools reviewed. The homeworks are to be solved using the programming language Python 3 and its libraries.
#
#   Õpiväljundid (ET):
#   - Kursuse läbinud üliõpilane on võimeline:
# - - Loetlema ning selgitama peamisi andmeteaduse alamvaldkondi, põhimõisteid ning põhiülesandeid
# - - Teostama etteantud andmestikul kirjeldavat analüüsi
# - - Valima ning teostama andmestikule sobivaid visualiseeringuid
# - - Rakendama tavalisemaid klasterdusmeetodeid ning tõlgendama nende tulemusi
# - - Valima ja rakendama lihtsamaid masinõppe algoritme, et luua ennustavaid mudeleid klassifikatsiooni ja regressiooni jaoks
# - - Kasutama lihtsamaid hindamismeetodeid, et mõõta masinõppe abil saadud mudelite ennustusväärtust
# - - Interpreteerima statistilise testi tulemusi
# - - Plaanima ja teostama lihtsat praktilist andmeteaduse projekti ning koostama selle lõppraporti
#
#   Õpiväljundid (EN):
#   - Upon successful completion of this course, students should be able to:
# - - List and explain the main subfields, concepts and tasks of data science
# - - Perform a descriptive analysis of a given dataset
# - - Choose and implement appropriate visualisations for the data
# - - Apply common clustering methods and interpret the results
# - - Choose and apply basic machine learning algorithms to build predictive models for classification and regression
# - - Use basic evaluation methods to measure predictive performance of models obtained by machine learning
# - - Interpret the results from a statistical test
# - - Plan and implement a simple practical data science project and produce a final report
#
#   Hindamise info:
#   Miinimumnõuded: See the grading and requirements information at the course web page https://courses.cs.ut.ee/2024/ids/fall/
# Hindamismeetod: See the grading and requirements information at the course web page https://courses.cs.ut.ee/2024/ids/fall/
# ──────────────────────────────────────────────────

# %%
print("=" * 60)
print("TUNNUSE 'KIRJELDUS' LOOMINE JA STATISTIKA")
print("=" * 60)

def build_kirjeldus(row):
    """Ühendab kõik aine veerud üheks suureks tekstiks RAGi jaoks."""
    parts = []
    if pd.notna(row.get('nimi_et')): parts.append(f"Aine: {row['nimi_et']}")
    if pd.notna(row.get('nimi_en')): parts.append(f"Course: {row['nimi_en']}")
    if pd.notna(row.get('aine_kood')): parts.append(f"Kood: {row['aine_kood']}")
    if pd.notna(row.get('eap')): parts.append(f"EAP: {row['eap']}")
    if pd.notna(row.get('semester')): parts.append(f"Semester: {row['semester']}")
    if pd.notna(row.get('keel_et')): parts.append(f"Keel: {row['keel_et']}")
    if pd.notna(row.get('linn')): parts.append(f"Linn: {row['linn']}")
    if pd.notna(row.get('oppeaste')): parts.append(f"Õppeaste: {row['oppeaste']}")
    if pd.notna(row.get('hindamisskaala')): parts.append(f"Hindamisskaala: {row['hindamisskaala']}")
    if pd.notna(row.get('kestus_semestrites')): parts.append(f"Kestus semestrites: {row['kestus_semestrites']}")
    if pd.notna(row.get('oppe_tuup')): parts.append(f"Õppe tüüp: {row['oppe_tuup']}")
    if pd.notna(row.get('aine_tuup')): parts.append(f"Aine tüüp: {row['aine_tuup']}")
    if pd.notna(row.get('kirjeldus_et')): parts.append(f"Kirjeldus: {row['kirjeldus_et']}")
    if pd.notna(row.get('kirjeldus_en')): parts.append(f"Description: {row['kirjeldus_en']}")
    if pd.notna(row.get('oppivaaljundid_et')): parts.append(f"Õpiväljundid: {row['oppivaaljundid_et']}")
    if pd.notna(row.get('oppivaaljundid_en')): parts.append(f"Learning outcomes: {row['oppivaaljundid_en']}")
    if pd.notna(row.get('hindamine_info')): parts.append(f"Hindamine: {row['hindamine_info']}")
    if pd.notna(row.get('eeldusained')): parts.append(f"Eeldusained: {row['eeldusained']}")
    return "\n".join(parts)

df_final['kirjeldus'] = df_final.apply(build_kirjeldus, axis=1)
df_final['kirjeldus_pikkus'] = df_final['kirjeldus'].str.len()

print("\nTunnuse 'kirjeldus' tähemärkide arvu statistika:")
print(df_final['kirjeldus_pikkus'].describe())

print(f"\nNäide (esimene aine):")
print(df_final['kirjeldus'].iloc[0][:500])
# Out:
# ============================================================
# TUNNUSE 'KIRJELDUS' LOOMINE JA STATISTIKA
# ============================================================
#
# Tunnuse 'kirjeldus' tähemärkide arvu statistika:
# count    2954.000000
# mean     2321.644888
# std      1019.140607
# min       273.000000
# 25%      1604.500000
# 50%      2124.000000
# 75%      2826.750000
# max      9110.000000
# Name: kirjeldus_pikkus, dtype: float64
#
# Näide (esimene aine):
# Aine: Rahvusvaheline eraõigus
# Course: Private International Law
# Kood: OIEO.06.046
# EAP: 6.0
# Semester: kevad
# Keel: eesti keel
# Linn: Tartu linn
# Õppeaste: magistriõpe
# Hindamisskaala: Eristav (A, B, C, D, E, F, mi)
# Kestus semestrites: 1
# Õppe tüüp: päevaõpe
# Aine tüüp: Tavaline aine
# Kirjeldus: Kursuse raames käsitletakse rahvusvahelise eraõiguse põhiteemasid, terminoloogiat ja kujunemist, tutvustatakse ja õpetatakse praktikas kasutama Eestis kehtivaid rahvusvahelise kohtualluvuse ja kohaldatava õiguse

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 5))
df_final['kirjeldus_pikkus'].hist(bins=50, ax=ax, edgecolor='black')
ax.set_xlabel('Tähemärkide arv')
ax.set_ylabel('Ainete arv')
ax.set_title('Tunnuse "kirjeldus" pikkuse jaotus')
ax.axvline(df_final['kirjeldus_pikkus'].median(), color='red', linestyle='--', label=f"Mediaan: {df_final['kirjeldus_pikkus'].median():.0f}")
ax.axvline(df_final['kirjeldus_pikkus'].mean(), color='orange', linestyle='--', label=f"Keskmine: {df_final['kirjeldus_pikkus'].mean():.0f}")
ax.legend()
plt.tight_layout()
plt.show()

df_final.drop(columns=['kirjeldus_pikkus']).to_csv(OUTPUT_FILE, index=False)
print(f"Lõplik andmestik salvestatud faili '{OUTPUT_FILE}' ({len(df_final)} rida, {len(df_final.columns) - 1} veergu).")
# Out:
# Lõplik andmestik salvestatud faili 'andmed_aasta.csv' (2954 rida, 21 veergu).
